# %%
from datetime import datetime, timedelta, timezone
import ccxt
import plotly.express as px
import logging
import pandas as pd
logging.basicConfig(level=logging.INFO, format='%(asctime)s|%(levelname)s|%(message)s')
log = logging.getLogger(__name__)

# %%
def dt2ts(dt):
    return int(dt.timestamp() * 1000)

def ts2dt(ts):
    return datetime.fromtimestamp(ts / 1000)
def str2dt(s):
    return datetime.fromisoformat(s)
def dt2str(dt):
    return dt.isoformat()

# %%
from pathlib import Path
import json

for exchange in ccxt.exchanges:
    try:
        print(exchange)
        markets = getattr(ccxt, exchange)().load_markets()
        Path(f"exchanges/{exchange}.json").write_text(json.dumps(markets, indent=4))
    except Exception as e:
        print(f"{exchange} failed with {e}")
        continue
# Out:
# ace
# alpaca
# alpaca failed with alpaca {"message": "forbidden."}
# ascendex
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 try:
#       6     print(exchange)
# ----> 7     markets = getattr(ccxt, exchange)().load_markets()
#       8     Path(f"exchanges/{exchange}.json").write_text(json.dumps(markets, indent=4))
#       9 except Exception as e:
#
# File ~/git/basis_trading/.venv/lib/python3.10/site-packages/ccxt/base/exchange.py:1494, in Exchange.load_markets(self, reload, params)
#    1492 currencies = None
#    1493 if self.has['fetchCurrencies'] is True:
# -> 1494     currencies = self.fetch_currencies()
#    1495 markets = self.fetch_markets(params)
#    1496 return self.set_markets(markets, currencies)
#
# File ~/git/basis_trading/.venv/lib/python3.10/site-packages/ccxt/ascendex.py:441, in ascendex.fetch_currencies(self, params)
#     421 margin = self.v1PublicGetMarginAssets(params)
#     422 #
#     423 #     {
#     424 #         "code":0,
#    (...)
#     439 #     }
#     440 #
# --> 441 cash = self.v1PublicGetCashAssets(params)
#     442 #
#     443 #     {
#     444 #         "code":0,
#    (...)
#     456 #     }
#     457 #
#     458 assetsData = self.safe_value(assets, 'data', [])
#
# File ~/git/basis_trading/.venv/lib/python3.10/site-packages/ccxt/base/types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/git/basis_trading/.venv/lib/python3.10/site-packages/ccxt/base/exchange.py:3598, in Exchange.request(self, path, api, method, params, headers, body, config)
#    3597 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 3598     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~/git/basis_trading/.venv/lib/python3.10/site-packages/ccxt/base/exchange.py:3589, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3587 if self.enableRateLimit:
#    3588     cost = self.calculate_rate_limiter_cost(api, method, path, params, config)
# -> 3589     self.throttle(cost)
#    3590 self.lastRestRequestTimestamp = self.milliseconds()
#    3591 request = self.sign(path, api, method, params, headers, body)
#
# File ~/git/basis_trading/.venv/lib/python3.10/site-packages/ccxt/base/exchange.py:516, in Exchange.throttle(self, cost)
#     514 if elapsed < sleep_time:
#     515     delay = sleep_time - elapsed
# --> 516     time.sleep(delay / 1000.0)
#
# KeyboardInterrupt:

# %%
from contextlib import contextmanager


@contextmanager
def supress():
    try:
        yield
    except Exception as e:
        log.exception(f"{exchange} failed with {e}")
        return

# %%
def print_futures(api, binance_api, results):
    for key, info in api.load_markets().items():
        with supress():
            if not info["future"] or not info["inverse"] or not info["active"]:
                continue
            if api.id == "deribit" and info["info"]["kind"] != "future":
                continue
                
            Path(f"infos/{api.id}_{info['id']}.json").write_text(json.dumps(info, indent=4))
            future_id = info["id"]
            future_price = api.fetch_ticker(future_id)["last"]
            if future_price is None:
                print(f"{future_id=} Last price is none")
                continue
            
            base_symbol = info["settle"] + "USDT"
            base_price = binance_api.fetch_ticker(base_symbol)["last"]
            period_yield = (future_price - base_price) / base_price * 100
            expiry_date = datetime.fromisoformat(info["expiryDatetime"][:len("2024-06-28")])
            days_till_expiry = (expiry_date - datetime.now()).days
            year_yield = period_yield / days_till_expiry * 365 if days_till_expiry else float("nan")
            result = dict(exchange_id=api.id,
                id=key,
                future_id=future_id,
                future_price=future_price,
                base_symbol=base_symbol,
                base_price=base_price,
                period_yield=period_yield,
                days_till_expiry=days_till_expiry,
                expiry_date=expiry_date,
                year_yield=year_yield
            )
            results.append(result)
            print(result)

# %%
# alpaca" # ccxt.base.errors.PermissionDenied: alpaca {"message": "forbidden."}
# coinbase # ccxt.base.errors.AuthenticationError: coinbase requires "apiKey" credential
# mercado # GET https://www.mercadobitcoin.net/api/coins 403 Forbidden
# zaif # GET https://api.zaif.jp/api/1/currency_pairs/all 403 Forbidden 
# binancecoinm # same as binance
EXCHANGE_IDS = "binance bitget bitmex bybit deribit htx krakenfutures kucoinfutures okx".split()

# %%
from pathlib import Path
import json
binance_api = ccxt.binance()
results = []
for exchange_id in EXCHANGE_IDS:
    with supress():
        api = getattr(ccxt, exchange_id)()
        print_futures(api=api, binance_api=binance_api, results=results)
# Out:
# {'exchange_id': 'binance', 'id': 'BTC/USD:BTC-240927', 'future_id': 'BTCUSD_240927', 'future_price': 62435.0, 'base_symbol': 'BTCUSDT', 'base_price': 60828.11, 'period_yield': 2.641689837149304, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.713519895105511}
# {'exchange_id': 'binance', 'id': 'BTC/USD:BTC-241227', 'future_id': 'BTCUSD_241227', 'future_price': 64563.3, 'base_symbol': 'BTCUSDT', 'base_price': 60828.1, 'period_yield': 6.140583052898257, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 12.38294372545781}
# {'exchange_id': 'binance', 'id': 'ETH/USD:ETH-240927', 'future_id': 'ETHUSD_240927', 'future_price': 3507.4, 'base_symbol': 'ETHUSDT', 'base_price': 3406.02, 'period_yield': 2.9764945596326537, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 12.071339047399094}
# {'exchange_id': 'binance', 'id': 'ETH/USD:ETH-241227', 'future_id': 'ETHUSD_241227', 'future_price': 3599.69, 'base_symbol': 'ETHUSDT', 'base_price': 3406.4, 'period_yield': 5.674318929074682, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.44268734316165}
# {'exchange_id': 'binance', 'id': 'ADA/USD:ADA-240927', 'future_id': 'ADAUSD_240927', 'future_price': 0.4048, 'base_symbol': 'ADAUSDT', 'base_price': 0.3942, 'period_yield': 2.6889903602232366, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.905349794238681}
# {'exchange_id': 'binance', 'id': 'LINK/USD:LINK-240927', 'future_id': 'LINKUSD_240927', 'future_price': 14.766, 'base_symbol': 'LINKUSDT', 'base_price': 14.365, 'period_yield': 2.791507135398537, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 11.321112271338512}
# {'exchange_id': 'binance', 'id': 'BCH/USD:BCH-240927', 'future_id': 'BCHUSD_240927', 'future_price': 398.46, 'base_symbol': 'BCHUSDT', 'base_price': 388.6, 'period_yield': 2.5373134328358096, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.290215588723006}
# {'exchange_id': 'binance', 'id': 'DOT/USD:DOT-240927', 'future_id': 'DOTUSD_240927', 'future_price': 6.44, 'base_symbol': 'DOTUSDT', 'base_price': 6.312, 'period_yield': 2.027883396704691, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 8.22419377552458}
# {'exchange_id': 'binance', 'id': 'XRP/USD:XRP-240927', 'future_id': 'XRPUSD_240927', 'future_price': 0.4882, 'base_symbol': 'XRPUSDT', 'base_price': 0.4749, 'period_yield': 2.8005895978100726, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 11.35794670222974}
# {'exchange_id': 'binance', 'id': 'LTC/USD:LTC-240927', 'future_id': 'LTCUSD_240927', 'future_price': 75.34, 'base_symbol': 'LTCUSDT', 'base_price': 72.89, 'period_yield': 3.3612292495541265, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 13.631651956525067}
# {'exchange_id': 'binance', 'id': 'BNB/USD:BNB-240927', 'future_id': 'BNBUSD_240927', 'future_price': 568.66, 'base_symbol': 'BNBUSDT', 'base_price': 571.7, 'period_yield': -0.5317474199755251, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': -2.156531203234074}
# {'exchange_id': 'binance', 'id': 'ADA/USD:ADA-241227', 'future_id': 'ADAUSD_241227', 'future_price': 0.411, 'base_symbol': 'ADAUSDT', 'base_price': 0.3942, 'period_yield': 4.261796042617956, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 8.594229588704717}
# {'exchange_id': 'binance', 'id': 'LINK/USD:LINK-241227', 'future_id': 'LINKUSD_241227', 'future_price': 15.034, 'base_symbol': 'LINKUSDT', 'base_price': 14.356, 'period_yield': 4.722764001114522, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 9.523805858601108}
# {'exchange_id': 'binance', 'id': 'BCH/USD:BCH-241227', 'future_id': 'BCHUSD_241227', 'future_price': 405.45, 'base_symbol': 'BCHUSDT', 'base_price': 388.6, 'period_yield': 4.336078229541936, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 8.744025159021032}
# {'exchange_id': 'binance', 'id': 'DOT/USD:DOT-241227', 'future_id': 'DOTUSD_241227', 'future_price': 6.668, 'base_symbol': 'DOTUSDT', 'base_price': 6.314, 'period_yield': 5.606588533417803, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.306103948604962}
# {'exchange_id': 'binance', 'id': 'XRP/USD:XRP-241227', 'future_id': 'XRPUSD_241227', 'future_price': 0.5017, 'base_symbol': 'XRPUSDT', 'base_price': 0.4748, 'period_yield': 5.66554338668914, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.4249908074118}
# {'exchange_id': 'binance', 'id': 'LTC/USD:LTC-241227', 'future_id': 'LTCUSD_241227', 'future_price': 77.38, 'base_symbol': 'LTCUSDT', 'base_price': 72.89, 'period_yield': 6.15996707367265, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 12.42203304911888}
# {'exchange_id': 'binance', 'id': 'BNB/USD:BNB-241227', 'future_id': 'BNBUSD_241227', 'future_price': 567.29, 'base_symbol': 'BNBUSDT', 'base_price': 571.8, 'period_yield': -0.7887373207415165, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': -1.590547635749467}
# {'exchange_id': 'bitget', 'id': 'BTC/USD:BTC-240927', 'future_id': 'BTCUSDU24', 'future_price': 62380.7, 'base_symbol': 'BTCUSDT', 'base_price': 60822.01, 'period_yield': 2.5627071515722597, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.393201225820832}
# {'exchange_id': 'bitget', 'id': 'ETH/USD:ETH-240927', 'future_id': 'ETHUSDU24', 'future_price': 3495.67, 'base_symbol': 'ETHUSDT', 'base_price': 3405.37, 'period_yield': 2.651694235868648, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.75409328991174}
# {'exchange_id': 'bitget', 'id': 'ETH/USD:ETH-241227', 'future_id': 'ETHUSDZ24', 'future_price': 3599.26, 'base_symbol': 'ETHUSDT', 'base_price': 3405.36, 'period_yield': 5.69396480841967, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.482304724161214}
# {'exchange_id': 'bitget', 'id': 'BTC/USD:BTC-241227', 'future_id': 'BTCUSDZ24', 'future_price': 64496.3, 'base_symbol': 'BTCUSDT', 'base_price': 60822.01, 'period_yield': 6.041053230565713, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 12.1822344152292}
# {'exchange_id': 'bitmex', 'id': 'BTC/USD:BTC-240726', 'future_id': 'XBTN24', 'future_price': 61300.0, 'base_symbol': 'BTCUSDT', 'base_price': 60814.01, 'period_yield': 0.7991415136084562, 'days_till_expiry': 27, 'expiry_date': datetime.datetime(2024, 7, 26, 0, 0), 'year_yield': 10.803209350632834}
# {'exchange_id': 'bitmex', 'id': 'BTC/USD:BTC-240830', 'future_id': 'XBTQ24', 'future_price': 62029.5, 'base_symbol': 'BTCUSDT', 'base_price': 60825.99, 'period_yield': 1.9786114455350452, 'days_till_expiry': 62, 'expiry_date': datetime.datetime(2024, 8, 30, 0, 0), 'year_yield': 11.648277058391798}
# {'exchange_id': 'bitmex', 'id': 'BTC/USD:BTC-240927', 'future_id': 'XBTU24', 'future_price': 61946.0, 'base_symbol': 'BTCUSDT', 'base_price': 60826.0, 'period_yield': 1.84131785749515, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 7.4675668665081085}
# {'exchange_id': 'bitmex', 'id': 'BTC/USD:BTC-241227', 'future_id': 'XBTZ24', 'future_price': 63884.5, 'base_symbol': 'BTCUSDT', 'base_price': 60820.1, 'period_yield': 5.038465901897566, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 10.16044228835697}
# {'exchange_id': 'bitmex', 'id': 'BTC/USD:BTC-250328', 'future_id': 'XBTH25', 'future_price': 65400.5, 'base_symbol': 'BTCUSDT', 'base_price': 60821.99, 'period_yield': 7.527721470474745, 'days_till_expiry': 272, 'expiry_date': datetime.datetime(2025, 3, 28, 0, 0), 'year_yield': 10.101538002659126}
# {'exchange_id': 'bitmex', 'id': 'BTC/USD:BTC-240628', 'future_id': 'XBTM24', 'future_price': 61616.17, 'base_symbol': 'BTCUSDT', 'base_price': 60822.33, 'period_yield': 1.3051785421571265, 'days_till_expiry': -1, 'expiry_date': datetime.datetime(2024, 6, 28, 0, 0), 'year_yield': -476.39016788735114}
# {'exchange_id': 'bybit', 'id': 'BTC/USD:BTC-240927', 'future_id': 'BTCUSDU24', 'future_price': 62412.0, 'base_symbol': 'BTCUSDT', 'base_price': 60847.99, 'period_yield': 2.5703560627064297, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.424221809864964}
# {'exchange_id': 'bybit', 'id': 'BTC/USD:BTC-241227', 'future_id': 'BTCUSDZ24', 'future_price': 64456.5, 'base_symbol': 'BTCUSDT', 'base_price': 60848.0, 'period_yield': 5.930351038653694, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.958995188445297}
# {'exchange_id': 'bybit', 'id': 'ETH/USD:ETH-240927', 'future_id': 'ETHUSDU24', 'future_price': 3502.15, 'base_symbol': 'ETHUSDT', 'base_price': 3406.31, 'period_yield': 2.8136018154542644, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 11.410718473786737}
# {'exchange_id': 'bybit', 'id': 'ETH/USD:ETH-241227', 'future_id': 'ETHUSDZ24', 'future_price': 3602.0, 'base_symbol': 'ETHUSDT', 'base_price': 3406.31, 'period_yield': 5.744926327903217, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.585072429197094}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-240705', 'future_id': 'ETH-5JUL24', 'future_price': 3406.75, 'base_symbol': 'ETHUSDT', 'base_price': 3406.32, 'period_yield': 0.012623593790361338, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': 0.767935288913648}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-240712', 'future_id': 'ETH-12JUL24', 'future_price': 3414.25, 'base_symbol': 'ETHUSDT', 'base_price': 3406.32, 'period_yield': 0.2328025552502359, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 6.536379435872009}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-240726', 'future_id': 'ETH-26JUL24', 'future_price': 3426.0, 'base_symbol': 'ETHUSDT', 'base_price': 3406.34, 'period_yield': 0.5771590622192692, 'days_till_expiry': 27, 'expiry_date': datetime.datetime(2024, 7, 26, 0, 0), 'year_yield': 7.802335470741973}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-240830', 'future_id': 'ETH-30AUG24', 'future_price': 3468.25, 'base_symbol': 'ETHUSDT', 'base_price': 3406.34, 'period_yield': 1.8174932625633335, 'days_till_expiry': 62, 'expiry_date': datetime.datetime(2024, 8, 30, 0, 0), 'year_yield': 10.699758723155108}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-240927', 'future_id': 'ETH-27SEP24', 'future_price': 3486.5, 'base_symbol': 'ETHUSDT', 'base_price': 3406.34, 'period_yield': 2.3532589230669823, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 9.543772299104985}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-241227', 'future_id': 'ETH-27DEC24', 'future_price': 3577.75, 'base_symbol': 'ETHUSDT', 'base_price': 3406.34, 'period_yield': 5.032087225585228, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 10.147579211815515}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-250328', 'future_id': 'ETH-28MAR25', 'future_price': 3666.0, 'base_symbol': 'ETHUSDT', 'base_price': 3406.35, 'period_yield': 7.622528512924394, 'days_till_expiry': 272, 'expiry_date': datetime.datetime(2025, 3, 28, 0, 0), 'year_yield': 10.228760688299278}
# {'exchange_id': 'deribit', 'id': 'ETH/USD:ETH-250627', 'future_id': 'ETH-27JUN25', 'future_price': 3753.0, 'base_symbol': 'ETHUSDT', 'base_price': 3406.35, 'period_yield': 10.176581971905414, 'days_till_expiry': 363, 'expiry_date': datetime.datetime(2025, 6, 27, 0, 0), 'year_yield': 10.232651294064672}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-240705', 'future_id': 'BTC-5JUL24', 'future_price': 60885.0, 'base_symbol': 'BTCUSDT', 'base_price': 60848.0, 'period_yield': 0.060807257428346036, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': 3.699108160224384}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-240712', 'future_id': 'BTC-12JUL24', 'future_price': 60985.0, 'base_symbol': 'BTCUSDT', 'base_price': 60850.0, 'period_yield': 0.2218570254724733, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 6.229062638265597}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-240726', 'future_id': 'BTC-26JUL24', 'future_price': 61247.5, 'base_symbol': 'BTCUSDT', 'base_price': 60851.92, 'period_yield': 0.6500698745413486, 'days_till_expiry': 27, 'expiry_date': datetime.datetime(2024, 7, 26, 0, 0), 'year_yield': 8.78798163731823}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-240830', 'future_id': 'BTC-30AUG24', 'future_price': 61912.5, 'base_symbol': 'BTCUSDT', 'base_price': 60851.91, 'period_yield': 1.742903386270039, 'days_till_expiry': 62, 'expiry_date': datetime.datetime(2024, 8, 30, 0, 0), 'year_yield': 10.260640903041358}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-240927', 'future_id': 'BTC-27SEP24', 'future_price': 62317.5, 'base_symbol': 'BTCUSDT', 'base_price': 60851.92, 'period_yield': 2.4084367428340827, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 9.76754901260489}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-241227', 'future_id': 'BTC-27DEC24', 'future_price': 64007.5, 'base_symbol': 'BTCUSDT', 'base_price': 60851.91, 'period_yield': 5.18568768014019, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 10.45732598481309}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-250328', 'future_id': 'BTC-28MAR25', 'future_price': 65677.5, 'base_symbol': 'BTCUSDT', 'base_price': 60851.92, 'period_yield': 7.930037375977622, 'days_till_expiry': 272, 'expiry_date': datetime.datetime(2025, 3, 28, 0, 0), 'year_yield': 10.641410449381736}
# {'exchange_id': 'deribit', 'id': 'BTC/USD:BTC-250627', 'future_id': 'BTC-27JUN25', 'future_price': 67107.5, 'base_symbol': 'BTCUSDT', 'base_price': 60851.92, 'period_yield': 10.280004312107165, 'days_till_expiry': 363, 'expiry_date': datetime.datetime(2025, 6, 27, 0, 0), 'year_yield': 10.336643454322632}
# {'exchange_id': 'htx', 'id': 'BTC/USD:BTC-240705', 'future_id': 'BTC240705', 'future_price': 60767.46, 'base_symbol': 'BTCUSDT', 'base_price': 60870.0, 'period_yield': -0.1684573681616574, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': -10.24782322983416}
# {'exchange_id': 'htx', 'id': 'BTC/USD:BTC-240712', 'future_id': 'BTC240712', 'future_price': 60924.47, 'base_symbol': 'BTCUSDT', 'base_price': 60874.94, 'period_yield': 0.08136352988602344, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 2.284437569876812}
# {'exchange_id': 'htx', 'id': 'BTC/USD:BTC-240927', 'future_id': 'BTC240927', 'future_price': 62155.22, 'base_symbol': 'BTCUSDT', 'base_price': 60877.99, 'period_yield': 2.0980160481645393, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 8.508620639778409}
# {'exchange_id': 'htx', 'id': 'ETH/USD:ETH-240705', 'future_id': 'ETH240705', 'future_price': 3402.947, 'base_symbol': 'ETHUSDT', 'base_price': 3407.95, 'period_yield': -0.14680379700405527, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': -8.930564317746695}
# {'exchange_id': 'htx', 'id': 'ETH/USD:ETH-240712', 'future_id': 'ETH240712', 'future_price': 3408.066, 'base_symbol': 'ETHUSDT', 'base_price': 3407.79, 'period_yield': 0.008099090612973215, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 0.22739754413347874}
# {'exchange_id': 'htx', 'id': 'ETH/USD:ETH-240927', 'future_id': 'ETH240927', 'future_price': 3488.272, 'base_symbol': 'ETHUSDT', 'base_price': 3407.8, 'period_yield': 2.361406185809019, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 9.576813975781022}
# {'exchange_id': 'htx', 'id': 'TRX/USD:TRX-240705', 'future_id': 'TRX240705', 'future_price': 0.12312, 'base_symbol': 'TRXUSDT', 'base_price': 0.12318, 'period_yield': -0.0487092060399452, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': -2.9631433674299994}
# {'exchange_id': 'htx', 'id': 'TRX/USD:TRX-240712', 'future_id': 'TRX240712', 'future_price': 0.12326, 'base_symbol': 'TRXUSDT', 'base_price': 0.12318, 'period_yield': 0.06494560805325275, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 1.8234728414951735}
# {'exchange_id': 'kucoinfutures', 'id': 'BTC/USD:BTC-240927', 'future_id': 'XBTMU24', 'future_price': 62650.0, 'base_symbol': 'BTCUSDT', 'base_price': 60873.99, 'period_yield': 2.917518631520625, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 11.832158894500312}
# {'exchange_id': 'okx', 'id': 'BTC/USD:BTC-240705', 'future_id': 'BTC-USD-240705', 'future_price': 60903.1, 'base_symbol': 'BTCUSDT', 'base_price': 60872.0, 'period_yield': 0.051090813510314345, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': 3.1080244885441224}
# {'exchange_id': 'okx', 'id': 'BTC/USD:BTC-240712', 'future_id': 'BTC-USD-240712', 'future_price': 60947.6, 'base_symbol': 'BTCUSDT', 'base_price': 60872.71, 'period_yield': 0.12302721531536778, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 3.454225660777634}
# {'exchange_id': 'okx', 'id': 'BTC/USD:BTC-240726', 'future_id': 'BTC-USD-240726', 'future_price': 61236.2, 'base_symbol': 'BTCUSDT', 'base_price': 60873.85, 'period_yield': 0.595247384550178, 'days_till_expiry': 27, 'expiry_date': datetime.datetime(2024, 7, 26, 0, 0), 'year_yield': 8.046862791141296}
# {'exchange_id': 'okx', 'id': 'BTC/USD:BTC-240830', 'future_id': 'BTC-USD-240830', 'future_price': 61976.2, 'base_symbol': 'BTCUSDT', 'base_price': 60873.86, 'period_yield': 1.8108593737936063, 'days_till_expiry': 62, 'expiry_date': datetime.datetime(2024, 8, 30, 0, 0), 'year_yield': 10.660704377978488}
# {'exchange_id': 'okx', 'id': 'BTC/USD:BTC-240927', 'future_id': 'BTC-USD-240927', 'future_price': 62145.6, 'base_symbol': 'BTCUSDT', 'base_price': 60873.85, 'period_yield': 2.089156509732833, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 8.472690289472045}
# {'exchange_id': 'okx', 'id': 'BTC/USD:BTC-241227', 'future_id': 'BTC-USD-241227', 'future_price': 63909.2, 'base_symbol': 'BTCUSDT', 'base_price': 60873.86, 'period_yield': 4.986278182457949, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 10.055201859652769}
# {'exchange_id': 'okx', 'id': 'ETH/USD:ETH-240705', 'future_id': 'ETH-USD-240705', 'future_price': 3407.66, 'base_symbol': 'ETHUSDT', 'base_price': 3408.49, 'period_yield': -0.02435095892902509, 'days_till_expiry': 6, 'expiry_date': datetime.datetime(2024, 7, 5, 0, 0), 'year_yield': -1.481350001515693}
# {'exchange_id': 'okx', 'id': 'ETH/USD:ETH-240712', 'future_id': 'ETH-USD-240712', 'future_price': 3414.35, 'base_symbol': 'ETHUSDT', 'base_price': 3408.23, 'period_yield': 0.1795653462354328, 'days_till_expiry': 13, 'expiry_date': datetime.datetime(2024, 7, 12, 0, 0), 'year_yield': 5.041642413533306}
# {'exchange_id': 'okx', 'id': 'ETH/USD:ETH-240726', 'future_id': 'ETH-USD-240726', 'future_price': 3428.07, 'base_symbol': 'ETHUSDT', 'base_price': 3408.16, 'period_yield': 0.5841861884418663, 'days_till_expiry': 27, 'expiry_date': datetime.datetime(2024, 7, 26, 0, 0), 'year_yield': 7.897331806714118}
# {'exchange_id': 'okx', 'id': 'ETH/USD:ETH-240830', 'future_id': 'ETH-USD-240830', 'future_price': 3463.86, 'base_symbol': 'ETHUSDT', 'base_price': 3408.15, 'period_yield': 1.6346111526781404, 'days_till_expiry': 62, 'expiry_date': datetime.datetime(2024, 8, 30, 0, 0), 'year_yield': 9.623114043992278}
# {'exchange_id': 'okx', 'id': 'ETH/USD:ETH-240927', 'future_id': 'ETH-USD-240927', 'future_price': 3488.1, 'base_symbol': 'ETHUSDT', 'base_price': 3408.15, 'period_yield': 2.3458474538972705, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 9.51371467413893}
# {'exchange_id': 'okx', 'id': 'ETH/USD:ETH-241227', 'future_id': 'ETH-USD-241227', 'future_price': 3584.15, 'base_symbol': 'ETHUSDT', 'base_price': 3408.15, 'period_yield': 5.164091956046535, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 10.413776596447432}
# {'exchange_id': 'okx', 'id': 'XRP/USD:XRP-240927', 'future_id': 'XRP-USD-240927', 'future_price': 0.4875, 'base_symbol': 'XRPUSDT', 'base_price': 0.4753, 'period_yield': 2.5667999158426236, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.409799658695086}
# {'exchange_id': 'okx', 'id': 'XRP/USD:XRP-241227', 'future_id': 'XRP-USD-241227', 'future_price': 0.4994, 'base_symbol': 'XRPUSDT', 'base_price': 0.4753, 'period_yield': 5.070481800967812, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 10.225004736758295}
# {'exchange_id': 'okx', 'id': 'EOS/USD:EOS-240927', 'future_id': 'EOS-USD-240927', 'future_price': 0.6134, 'base_symbol': 'EOSUSDT', 'base_price': 0.5956, 'period_yield': 2.988582941571512, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 12.120364151928909}
# {'exchange_id': 'okx', 'id': 'ETC/USD:ETC-240927', 'future_id': 'ETC-USD-240927', 'future_price': 24.61, 'base_symbol': 'ETCUSDT', 'base_price': 23.85, 'period_yield': 3.1865828092243103, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 12.923363615187482}
# {'exchange_id': 'okx', 'id': 'LTC/USD:LTC-240927', 'future_id': 'LTC-USD-240927', 'future_price': 74.85, 'base_symbol': 'LTCUSDT', 'base_price': 72.94, 'period_yield': 2.6185906224293896, 'days_till_expiry': 90, 'expiry_date': datetime.datetime(2024, 9, 27, 0, 0), 'year_yield': 10.619839746519192}
# {'exchange_id': 'okx', 'id': 'LTC/USD:LTC-241227', 'future_id': 'LTC-USD-241227', 'future_price': 77.05, 'base_symbol': 'LTCUSDT', 'base_price': 72.94, 'period_yield': 5.634768302714559, 'days_till_expiry': 181, 'expiry_date': datetime.datetime(2024, 12, 27, 0, 0), 'year_yield': 11.362930555197869}

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(pd.DataFrame(results).sort_values(["days_till_expiry", "period_yield"]))
# Out:
#       exchange_id                    id       future_id  future_price  \
# 27         bitmex    BTC/USD:BTC-240628          XBTM24   61616.17000
# 48            htx    BTC/USD:BTC-240705       BTC240705   60767.46000
# 51            htx    ETH/USD:ETH-240705       ETH240705    3402.94700
# 54            htx    TRX/USD:TRX-240705       TRX240705       0.12312
# 63            okx    ETH/USD:ETH-240705  ETH-USD-240705    3407.66000
# 32        deribit    ETH/USD:ETH-240705      ETH-5JUL24    3406.75000
# 57            okx    BTC/USD:BTC-240705  BTC-USD-240705   60903.10000
# 40        deribit    BTC/USD:BTC-240705      BTC-5JUL24   60885.00000
# 52            htx    ETH/USD:ETH-240712       ETH240712    3408.06600
# 55            htx    TRX/USD:TRX-240712       TRX240712       0.12326
# 49            htx    BTC/USD:BTC-240712       BTC240712   60924.47000
# 58            okx    BTC/USD:BTC-240712  BTC-USD-240712   60947.60000
# 64            okx    ETH/USD:ETH-240712  ETH-USD-240712    3414.35000
# 41        deribit    BTC/USD:BTC-240712     BTC-12JUL24   60985.00000
# 33        deribit    ETH/USD:ETH-240712     ETH-12JUL24    3414.25000
# 34        deribit    ETH/USD:ETH-240726     ETH-26JUL24    3426.00000
# 65            okx    ETH/USD:ETH-240726  ETH-USD-240726    3428.07000
# 59            okx    BTC/USD:BTC-240726  BTC-USD-240726   61236.20000
# 42        deribit    BTC/USD:BTC-240726     BTC-26JUL24   61247.50000
# 22         bitmex    BTC/USD:BTC-240726          XBTN24   61300.00000
# 66            okx    ETH/USD:ETH-240830  ETH-USD-240830    3463.86000
# 43        deribit    BTC/USD:BTC-240830     BTC-30AUG24   61912.50000
# 60            okx    BTC/USD:BTC-240830  BTC-USD-240830   61976.20000
# 35        deribit    ETH/USD:ETH-240830     ETH-30AUG24    3468.25000
# 23         bitmex    BTC/USD:BTC-240830          XBTQ24   62029.50000
# 10        binance    BNB/USD:BNB-240927   BNBUSD_240927     568.66000
# 24         bitmex    BTC/USD:BTC-240927          XBTU24   61946.00000
# 7         binance    DOT/USD:DOT-240927   DOTUSD_240927       6.44000
# 61            okx    BTC/USD:BTC-240927  BTC-USD-240927   62145.60000
# 50            htx    BTC/USD:BTC-240927       BTC240927   62155.22000
# 67            okx    ETH/USD:ETH-240927  ETH-USD-240927    3488.10000
# 36        deribit    ETH/USD:ETH-240927     ETH-27SEP24    3486.50000
# 53            htx    ETH/USD:ETH-240927       ETH240927    3488.27200
# 44        deribit    BTC/USD:BTC-240927     BTC-27SEP24   62317.50000
# 6         binance    BCH/USD:BCH-240927   BCHUSD_240927     398.46000
# 18         bitget    BTC/USD:BTC-240927       BTCUSDU24   62380.70000
# 69            okx    XRP/USD:XRP-240927  XRP-USD-240927       0.48750
# 28          bybit    BTC/USD:BTC-240927       BTCUSDU24   62412.00000
# 73            okx    LTC/USD:LTC-240927  LTC-USD-240927      74.85000
# 0         binance    BTC/USD:BTC-240927   BTCUSD_240927   62435.00000
# 19         bitget    ETH/USD:ETH-240927       ETHUSDU24    3495.67000
# 4         binance    ADA/USD:ADA-240927   ADAUSD_240927       0.40480
# 5         binance  LINK/USD:LINK-240927  LINKUSD_240927      14.76600
# 8         binance    XRP/USD:XRP-240927   XRPUSD_240927       0.48820
# 30          bybit    ETH/USD:ETH-240927       ETHUSDU24    3502.15000
# 56  kucoinfutures    BTC/USD:BTC-240927         XBTMU24   62650.00000
# 2         binance    ETH/USD:ETH-240927   ETHUSD_240927    3507.40000
# 71            okx    EOS/USD:EOS-240927  EOS-USD-240927       0.61340
# 72            okx    ETC/USD:ETC-240927  ETC-USD-240927      24.61000
# 9         binance    LTC/USD:LTC-240927   LTCUSD_240927      75.34000
# 17        binance    BNB/USD:BNB-241227   BNBUSD_241227     567.29000
# 11        binance    ADA/USD:ADA-241227   ADAUSD_241227       0.41100
# 13        binance    BCH/USD:BCH-241227   BCHUSD_241227     405.45000
# 12        binance  LINK/USD:LINK-241227  LINKUSD_241227      15.03400
# 62            okx    BTC/USD:BTC-241227  BTC-USD-241227   63909.20000
# 37        deribit    ETH/USD:ETH-241227     ETH-27DEC24    3577.75000
# 25         bitmex    BTC/USD:BTC-241227          XBTZ24   63884.50000
# 70            okx    XRP/USD:XRP-241227  XRP-USD-241227       0.49940
# 68            okx    ETH/USD:ETH-241227  ETH-USD-241227    3584.15000
# 45        deribit    BTC/USD:BTC-241227     BTC-27DEC24   64007.50000
# 14        binance    DOT/USD:DOT-241227   DOTUSD_241227       6.66800
# 74            okx    LTC/USD:LTC-241227  LTC-USD-241227      77.05000
# 15        binance    XRP/USD:XRP-241227   XRPUSD_241227       0.50170
# 3         binance    ETH/USD:ETH-241227   ETHUSD_241227    3599.69000
# 20         bitget    ETH/USD:ETH-241227       ETHUSDZ24    3599.26000
# 31          bybit    ETH/USD:ETH-241227       ETHUSDZ24    3602.00000
# 29          bybit    BTC/USD:BTC-241227       BTCUSDZ24   64456.50000
# 21         bitget    BTC/USD:BTC-241227       BTCUSDZ24   64496.30000
# 1         binance    BTC/USD:BTC-241227   BTCUSD_241227   64563.30000
# 16        binance    LTC/USD:LTC-241227   LTCUSD_241227      77.38000
# 26         bitmex    BTC/USD:BTC-250328          XBTH25   65400.50000
# 38        deribit    ETH/USD:ETH-250328     ETH-28MAR25    3666.00000
# 46        deribit    BTC/USD:BTC-250328     BTC-28MAR25   65677.50000
# 37   10.147579
# 25   10.160442
# 70   10.225005
# 68   10.413777
# 45   10.457326
# 14   11.306104
# 74   11.362931
# 15   11.424991
# 3    11.442687
# 20   11.482305
# 31   11.585072
# 29   11.958995
# 21   12.182234
# 1    12.382944
# 16   12.422033
# 26   10.101538
# 38   10.228761
# 46   10.641410
# 39   10.232651
# 47   10.336643

# %%
def to_df(data):
    df = pd.DataFrame(data, columns=['date', 'open', 'high', 'low', 'close', 'volume'])
    df['date'] = pd.to_datetime(df['date'], unit='ms', utc=True)
    df.set_index('date', inplace=True)
    df = df.sort_index(ascending=True)
    return df

# %%
def get_prices(exchange_id: str, symbol: str, since: datetime, until: datetime, timeframe: str ='1h') -> pd.DataFrame:
    exchange = getattr(ccxt, exchange_id)()
    all_candles = []

    # Handle pagination to fetch all historical data within the given timeframe
    since_ts = dt2ts(since)
    until_ts = dt2ts(until)
    
    while since_ts < until_ts:
        candles = exchange.fetch_ohlcv(symbol=symbol, timeframe=timeframe, since=since_ts, limit=100)
        if not candles:
            break
        print(f"received {len(candles)} candles {ts2dt(candles[0][0])}->{ts2dt(candles[-1][0])}")
        since_ts = candles[-1][0] + 1  # Prepare 'since' for the next iteration
        all_candles += candles
        
    return all_candles

# %%
def merge(btc_fut_df: pd.DataFrame, btc_df: pd.DataFrame, expire: datetime) -> pd.DataFrame:
    merged_df = pd.merge(btc_df["close"], btc_fut_df["close"], left_index=True, right_index=True)
    merged_df.columns = ["spot", "futures"]
    merged_df["days_to_expiry"] = (expire - merged_df.index).days
    merged_df["yield"] = round(merged_df.futures / merged_df.spot * 100 - 100, 2)
    merged_df["apy"] = round((merged_df.futures / merged_df.spot * 100 - 100) / merged_df.days_to_expiry * 365, 2)
    merged_df["apy_quarter"] = round((merged_df.futures / merged_df.spot * 100 - 100) * 4, 2)
    return merged_df

# %%
since = str2dt('2024-06-20 00:00:00+00:00')
expire = str2dt('2024-06-24 00:00:00+00:00')
until = datetime.now(tz=timezone.utc)
timeframe = '1m'

# %%
btc_fut_df = to_df(get_prices(exchange_id="okx", symbol='ETC-USD-240927', since=since, until=until, timeframe=timeframe))
btc_df = to_df(get_prices(exchange_id="binance", symbol='ETCUSDT', since=since, until=until, timeframe=timeframe))
merged_df = merge(btc_fut_df=btc_fut_df, btc_df=btc_df, expire=expire)
print(f"{len(btc_fut_df)=} {len(btc_df)=} {len(merged_df)=}")
display(merged_df)
px.line(merged_df, y=["yield"], title="yield")
# Out:
# received 100 candles 2024-06-20 03:00:00->2024-06-20 04:39:00
# received 100 candles 2024-06-20 04:40:00->2024-06-20 06:19:00
# received 100 candles 2024-06-20 06:20:00->2024-06-20 07:59:00
# received 100 candles 2024-06-20 08:00:00->2024-06-20 09:39:00
# received 100 candles 2024-06-20 09:40:00->2024-06-20 11:19:00
# received 100 candles 2024-06-20 11:20:00->2024-06-20 12:59:00
# received 100 candles 2024-06-20 13:00:00->2024-06-20 14:39:00
# received 100 candles 2024-06-20 14:40:00->2024-06-20 16:19:00
# received 100 candles 2024-06-27 11:40:00->2024-06-27 13:19:00
# received 100 candles 2024-06-27 13:20:00->2024-06-27 14:59:00
# received 100 candles 2024-06-27 15:00:00->2024-06-27 16:39:00
# received 100 candles 2024-06-27 16:40:00->2024-06-27 18:19:00
# received 100 candles 2024-06-27 18:20:00->2024-06-27 19:59:00
# received 100 candles 2024-06-27 20:00:00->2024-06-27 21:39:00
# received 100 candles 2024-06-27 21:40:00->2024-06-27 23:19:00
# received 100 candles 2024-06-27 23:20:00->2024-06-28 00:59:00
# received 100 candles 2024-06-28 01:00:00->2024-06-28 02:39:00
# received 100 candles 2024-06-28 02:40:00->2024-06-28 04:19:00
# received 100 candles 2024-06-28 04:20:00->2024-06-28 05:59:00
# received 100 candles 2024-06-28 06:00:00->2024-06-28 07:39:00
# received 100 candles 2024-06-28 07:40:00->2024-06-28 09:19:00
# received 100 candles 2024-06-28 09:20:00->2024-06-28 10:59:00
# received 100 candles 2024-06-28 11:00:00->2024-06-28 12:39:00
# received 100 candles 2024-06-28 12:40:00->2024-06-28 14:19:00
# received 100 candles 2024-06-28 14:20:00->2024-06-28 15:59:00
# received 100 candles 2024-06-28 16:00:00->2024-06-28 17:39:00
# received 34 candles 2024-06-28 17:40:00->2024-06-28 18:13:00
# len(btc_fut_df)=12433 len(btc_df)=12434 len(merged_df)=12433
#                             spot  futures  days_to_expiry  yield     apy  \
# date
# 2024-06-20 00:00:00+00:00  23.96    24.47               4   2.13  194.23
# 2024-06-20 00:01:00+00:00  23.91    24.47               3   2.34  284.96
# 2024-06-20 00:02:00+00:00  23.90    24.47               3   2.38  290.17
# 2024-06-20 00:03:00+00:00  23.92    24.47               3   2.30  279.75
# 2024-06-20 00:04:00+00:00  23.91    24.47               3   2.34  284.96
# ...                          ...      ...             ...    ...     ...
# 2024-06-28 15:08:00+00:00  23.85    24.61              -5   3.19 -232.62
# 2024-06-28 15:09:00+00:00  23.84    24.61              -5   3.23 -235.78
# 2024-06-28 15:10:00+00:00  23.84    24.61              -5   3.23 -235.78
# 2024-06-28 15:11:00+00:00  23.85    24.61              -5   3.19 -232.62
# 2024-06-28 15:12:00+00:00  23.85    24.61              -5   3.19 -232.62
#
#                            apy_quarter
# date
# 2024-06-20 00:00:00+00:00         8.51
# 2024-06-20 00:01:00+00:00         9.37
# 2024-06-20 00:02:00+00:00         9.54
# 2024-06-20 00:03:00+00:00         9.20
# 2024-06-20 00:04:00+00:00         9.37
# ...                                ...
# 2024-06-28 15:08:00+00:00        12.75
# 2024-06-28 15:09:00+00:00        12.92
# 2024-06-28 15:10:00+00:00        12.92
# 2024-06-28 15:11:00+00:00        12.75
# 2024-06-28 15:12:00+00:00        12.75
#
# [12433 rows x 6 columns]

# %%
from_ts = ex.parse8601('2024-04-05 00:00:00')
ohlcv_list = []
ohlcv = ex.fetch_ohlcv('BTC/USDT', '5m', since=from_ts, limit=1000)
ohlcv_list.append(ohlcv)
while True:
    from_ts = ohlcv[-1][0]
    new_ohlcv = ex.fetch_ohlcv('BTC/USDT', '5m', since=from_ts, limit=1000,)
    ohlcv.extend(new_ohlcv)
    if len(new_ohlcv)!=1000:
    	break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from_ts = ex.parse8601('2024-04-05 00:00:00')
#       2 ohlcv_list = []
#       3 ohlcv = ex.fetch_ohlcv('BTC/USDT', '5m', since=from_ts, limit=1000)
#
# NameError: name 'ex' is not defined

# %%
dd

# %%
ccxt.deribit().fetch_ticker('BTC-FS-27SEP24_28JUN24')
# Out:
# {'symbol': 'BTC-FS-27SEP24_28JUN24',
#  'timestamp': 1712785096183,
#  'datetime': '2024-04-10T21:38:16.183Z',
#  'high': 2724.5,
#  'low': 2720.0,
#  'bid': 2860.5,
#  'bidVolume': 50000.0,
#  'ask': 2872.5,
#  'askVolume': 50000.0,
#  'vwap': None,
#  'open': None,
#  'close': 2720.0,
#  'last': 2720.0,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': None,
#  'quoteVolume': 0.0,
#  'info': {'best_bid_amount': '50000.0',
#   'best_ask_amount': '50000.0',
#   'implied_bid': '2855.0',
#   'implied_ask': '2882.5',
#   'combo_state': 'active',
#   'best_bid_price': '2860.5',
#   'best_ask_price': '2872.5',
#   'max_price': '3268.0',
#   'min_price': '2495.0',
#   'last_price': '2720.0',
#   'settlement_price': '2850.96',
#   'instrument_name': 'BTC-FS-27SEP24_28JUN24',
#   'mark_price': '2881.46',
#   'index_price': '69698.26',
#   'stats': {'volume_notional': '91010.0',
#    'volume_usd': '91010.0',
#    'volume': '0.0',
#    'price_change': '0.0',
#    'low': '2720.0',
#    'high': '2724.5'},
#   'state': 'open',
#   'timestamp': '1712785096183'}}

# %%
binance.fetch_ticker('ETH/USDT')["last"]
# Out:
# 3538.29

# %%
# show all rows
pd.set_option('display.max_rows', None)
df[df.strategy_name == "bnn_s_ACH"][df.metric == "adj_profit"]
# Out:
# /var/folders/4_/kgw4zz_50zn3r6p_mdtgrwgm0000gp/T/ipykernel_98276/3074275559.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.strategy_name == "bnn_s_ACH"][df.metric == "adj_profit"]
#      strategy_name name  ML:Params:P2  ML:Params:P1      metric field_name  \
# 0        bnn_s_ACH   ML           0.1           0.6  adj_profit      value
# 1        bnn_s_ACH   ML           0.1           0.6  adj_profit      value
# 34       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 35       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 36       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 37       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 38       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 39       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 40       bnn_s_ACH   ML           0.1           0.7  adj_profit      value
# 153      bnn_s_ACH   ML           0.2           0.2  adj_profit      value
# 154      bnn_s_ACH   ML           0.2           0.2  adj_profit      value
# 187      bnn_s_ACH   ML           0.2           0.6  adj_profit      value
# 188      bnn_s_ACH   ML           0.2           0.6  adj_profit      value
# 221      bnn_s_ACH   ML           0.2           0.7  adj_profit      value
# 222      bnn_s_ACH   ML           0.2           0.7  adj_profit      value
# 223      bnn_s_ACH   ML           0.2           0.7  adj_profit      value
# 272      bnn_s_ACH   ML           0.3           0.4  adj_profit      value
# 289      bnn_s_ACH   ML           0.3           0.5  adj_profit      value
# 290      bnn_s_ACH   ML           0.3           0.5  adj_profit      value
# 323      bnn_s_ACH   ML           0.3           0.7  adj_profit      value
# 324      bnn_s_ACH   ML           0.3           0.7  adj_profit      value
# 325      bnn_s_ACH   ML           0.3           0.7  adj_profit      value
# 326      bnn_s_ACH   ML           0.3           0.7  adj_profit      value
# 327      bnn_s_ACH   ML           0.3           0.7  adj_profit      value
# 408      bnn_s_ACH   ML           0.4           0.1  adj_profit      value
# 425      bnn_s_ACH   ML           0.4           0.3  adj_profit      value
# 442      bnn_s_ACH   ML           0.4           0.7  adj_profit      value
# 443      bnn_s_ACH   ML           0.4           0.7  adj_profit      value
# 444      bnn_s_ACH   ML           0.4           0.7  adj_profit      value
# 445      bnn_s_ACH   ML           0.4           0.7  adj_profit      value
# 446      bnn_s_ACH   ML           0.4           0.7  adj_profit      value
# 527      bnn_s_ACH   ML           0.5           0.1  adj_profit      value
# 528      bnn_s_ACH   ML           0.5           0.1  adj_profit      value
# 561      bnn_s_ACH   ML           0.5           0.2  adj_profit      value
# 578      bnn_s_ACH   ML           0.5           0.3  adj_profit      value
# 595      bnn_s_ACH   ML           0.5           0.5  adj_profit      value
# 596      bnn_s_ACH   ML           0.5           0.5  adj_profit      value
# 629      bnn_s_ACH   ML           0.5           0.6  adj_profit      value
# 630      bnn_s_ACH   ML           0.5           0.6  adj_profit      value
# 631      bnn_s_ACH   ML           0.5           0.6  adj_profit      value
# 632      bnn_s_ACH   ML           0.5           0.6  adj_profit      value
# 697      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 698      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 699      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 700      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 701      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 702      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 703      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 704      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 705      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 706      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 707      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 708      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 709      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 710      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 711      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 712      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 713      bnn_s_ACH   ML           0.5           0.7  adj_profit      value
# 986      bnn_s_ACH   ML           0.6           0.1  adj_profit      value
# 987      bnn_s_ACH   ML           0.6           0.1  adj_profit      value
# 1020     bnn_s_ACH   ML           0.6           0.2  adj_profit      value
# 1021     bnn_s_ACH   ML           0.6           0.2  adj_profit      value
# 1022     bnn_s_ACH   ML           0.6           0.2  adj_profit      value
# 1023     bnn_s_ACH   ML           0.6           0.2  adj_profit      value
# 1088     bnn_s_ACH   ML           0.6           0.3  adj_profit      value
# 1089     bnn_s_ACH   ML           0.6           0.3  adj_profit      value
# 1090     bnn_s_ACH   ML           0.6           0.3  adj_profit      value
# 1091     bnn_s_ACH   ML           0.6           0.3  adj_profit      value
# 1092     bnn_s_ACH   ML           0.6           0.3  adj_profit      value
# 1173     bnn_s_ACH   ML           0.6           0.4  adj_profit      value
# 1174     bnn_s_ACH   ML           0.6           0.4  adj_profit      value
# 1175     bnn_s_ACH   ML           0.6           0.4  adj_profit      value
# 1176     bnn_s_ACH   ML           0.6           0.4  adj_profit      value
# 1241     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1242     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1243     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1244     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1245     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1246     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1247     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1248     bnn_s_ACH   ML           0.6           0.5  adj_profit      value
# 1377     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1378     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1379     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1380     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1381     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1382     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1383     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1384     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1385     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1386     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1387     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1388     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1389     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1390     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1391     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1392     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1393     bnn_s_ACH   ML           0.6           0.6  adj_profit      value
# 1666     bnn_s_ACH   ML           0.6           0.7  adj_profit      value
# 
# 1876  83.9129
# 1877  83.9129
# 1878  83.9129
# 1879  83.9129
# 1880  83.9129
# 1881  83.9129
# 1882  83.9129
# 1883  83.9129
# 1884  83.9129
# 1885  83.9129
# 1886  83.9129
# 1887  83.9129
# 1888  83.9129
# 1889  83.9129
# 1890  83.9129
# 1891  83.9129
# 1892  83.9129
# 1893  83.9129
# 1894  83.9129
# 1895  83.9129
# 1896  83.9129
# 1897  83.9129
# 1898  83.9129
# 1899  83.9129
# 1900  83.9129
# 1901  83.9129
# 1902  83.9129
# 1903  83.9129
# 1904  83.9129
# 1905  83.9129
# 1906  83.9129
# 1907  83.9129
# 1908  83.9129
# 1909  83.9129
# 1910  83.9129
# 1911  83.9129
# 1912  83.9129
# 1913  83.9129
# 1914  83.9129
# 1915  83.9129
# 1916  83.9129
# 1917  83.9129
# 1918  83.9129
# 1919  83.9129
# 1920  83.9129
# 1921  83.9129
# 1922  83.9129
# 1923  83.9129
# 1924  83.9129
# 1925  83.9129
# 1926  83.9129
# 1927  83.9129
# 1928  83.9129
# 1929  83.9129
# 1930  83.9129
# 1931  83.9129
# 1932  83.9129
# 6205 -33.7276
# 6222 -56.6277
# 6223 -56.6277
# 6256 -12.9410
# 6257 -12.9410
# 6258 -12.9410
# 6259 -12.9410
# 6324  74.0912
# 6325  74.0912
# 6326  74.0912
# 6327  74.0912
# 6328  74.0912
# 6329  74.0912
# 6330  74.0912
# 6331  74.0912
# 6332  74.0912
# 6333  74.0912
# 6334  74.0912
# 6335  74.0912
# 6336  74.0912
# 6337  74.0912
# 6338  74.0912
# 6339  74.0912
# 6340  74.0912
# 6341  74.0912
# 6342  74.0912
# 6343  74.0912

# %%
ccxt.deribit().fetch_ticker("BTC-FS-27DEC24_12APR24")

# %%
ccxt.deribit().fetch_ticker("BTC-FS-27DEC24_12APR24")
# Out:
# {'symbol': 'BTC-FS-27DEC24_12APR24',
#  'timestamp': 1712783021770,
#  'datetime': '2024-04-10T21:03:41.770Z',
#  'high': None,
#  'low': None,
#  'bid': 7434.5,
#  'bidVolume': 300000.0,
#  'ask': 7461.5,
#  'askVolume': 50000.0,
#  'vwap': None,
#  'open': None,
#  'close': 8037.5,
#  'last': 8037.5,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': None,
#  'quoteVolume': 0.0,
#  'info': {'best_bid_amount': '300000.0',
#   'best_ask_amount': '50000.0',
#   'implied_bid': '7427.5',
#   'implied_ask': '7467.5',
#   'combo_state': 'active',
#   'best_bid_price': '7434.5',
#   'best_ask_price': '7461.5',
#   'max_price': '8004.5',
#   'min_price': '6938.5',
#   'last_price': '8037.5',
#   'settlement_price': '7367.68',
#   'instrument_name': 'BTC-FS-27DEC24_12APR24',
#   'mark_price': '7471.32',
#   'index_price': '69770.65',
#   'stats': {'volume_notional': '0.0',
#    'volume_usd': '0.0',
#    'volume': '0.0',
#    'price_change': None,
#    'low': None,
#    'high': None},
#   'state': 'open',
#   'timestamp': '1712783021770'}}
